# %% [markdown]
# ## Working With String

# %%
message = "Hello World"

print(message[0:5])
# Out:
# Hello

# %%
message.find('Universe')
# Out:
# -1

# %%
message.find('Hello')
# Out:
# 0

# %%
message.replace('World','Sujeet') # it did not replace original value
# Out:
# 'Hello Sujeet'

# %%
message
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 message
#
# NameError: name 'message' is not defined

# %%
text = ('Put several strings within parentheses '
        'to have them joined together.')

text
# Out:
# 'Put several strings within parentheses to have them joined together.'

# %%
greeting = 'Hello'
name = 'Sujeet'

message = '{}, {}, Welcome!'.format(greeting, name)

message
# Out:
# 'Hello, Sujeet, Welcome!'

# %%
print(dir(name)) # method available to string
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
print(help(str.__add__))
# Out:
# Help on wrapper_descriptor:
#
# __add__(self, value, /) unbound builtins.str method
#     Return self+value.
#
# None

# %%
print(help(str.__contains__))
# Out:
# Help on wrapper_descriptor:
#
# __contains__(self, key, /) unbound builtins.str method
#     Return bool(key in self).
#
# None

# %%
name.__contains__('Sujeet')
# Out:
# True

# %%
name.__add__(' Universe').__add__(" test")
# Out:
# 'Sujeet Universe test'

# %%
"{}".format("test")
# Out:
# 'test'

# %%
"hello".__format__(">10")
# Out:
# '     hello'

# %%
"hello".__format__("<10")
# Out:
# 'hello     '

# %%
"hello world".capitalize()  # Returns: "Hello world"
# Out:
# 'Hello world'

# %%
"Straße".casefold()  # Returns: "strasse" Aggressively lowers text (better than .lower() for matching international characters).
# Out:
# 'strasse'

# %%
"test".center(10, "-")  # Returns: "---test---" Centers the string inside a specified width padding.
# Out:
# '---test---'

# %%
"pandas data data".count("data")  # Returns: 2
# Out:
# 2

# %%
"hello".encode("utf-8")  # Returns: b'hello' , convert string into bytes
# Out:
# b'hello'

# %%
"report.csv".endswith(".csv")  # Returns: True
# Out:
# True

# %%
"a\tb".expandtabs(4)  # Returns: "a   b"  Replaces tab characters (\t) with spaces.
# Out:
# 'a   b'

# %%
"pandas".find("d")  # Returns: 3
# Out:
# 3

# %%
"Hello {}".format("Demser")  # Returns: "Hello Demser"
# Out:
# 'Hello Demser'

# %%
"Age: {age}".format_map({"age": 22})  # Returns: "Age: 22"
# Out:
# 'Age: 22'

# %%
"pandas".index("d")  # Returns: 3
# Out:
# 3

# %%
"Python3".isalnum()  # Returns: True
# Out:
# True

# %%
"Python".isalpha()  # Returns: True
# Out:
# True

# %%
"hello".isascii()  # Returns: True
# Out:
# True

# %%
"123".isdecimal()  # Returns: True
# Out:
# True

# %%
"xxx".isdecimal()
# Out:
# False

# %%
"123".isdigit()  # Returns: True
# Out:
# True

# %%
"pandas".islower()  # Returns: True
# Out:
# True

# %%
"123".isnumeric()  # Returns: True
# Out:
# True

# %%
"Hello".isprintable()  # Returns: True
# Out:
# True

# %%
"   ".isspace()  # Returns: True
# Out:
# True

# %%
"PANDAS".isupper()  # Returns: True
# Out:
# True

# %%
", ".join(["python", "scala"])  # Returns: "python, scala"
# Out:
# 'python, scala'

# %%
"test".ljust(10, "-")  # Returns: "test------"
# Out:
# 'test------'

# %%
"PANDAS".lower()  # Returns: "pandas"
# Out:
# 'pandas'

# %%
"  hello".lstrip()  # Returns: "hello"
# Out:
# 'hello'

# %%
table = str.maketrans("a", "x")  # Used with .translate() Creates a translation table mapping characters to other characters.

# %%
table
# Out:
# {97: 120}

# %%
"a-b-c".partition("-")  # Returns: ('a', '-', 'b-c') Splits a string into exactly 3 parts based on the first match of a separator
# Out:
# ('a', '-', 'b-c')

# %%
"test_file.csv".removeprefix("test_")  # Returns: "file.csv"
# Out:
# 'file.csv'

# %%
"test_file.csv".removesuffix(".csv")  # Returns: "test_file"
# Out:
# 'test_file'

# %%
"I love Scala".replace("Scala", "Python")  # Returns: "I love Python"
# Out:
# 'I love Python'

# %%
"data data".rfind("data")  # Returns: 5 search from right to left
# Out:
# 5

# %%
"data data".rindex("data")  # Returns: 5
# Out:
# 5

# %%
"test".rjust(10, "-")  # Returns: "------test"
# Out:
# '------test'

# %%
"a-b-c".rsplit("-", maxsplit=1)  # Returns: ['a-b', 'c']
# Out:
# ['a-b', 'c']

# %%
"python,scala,golang".split(",")  # Returns: ['python', 'scala', 'golang']
# Out:
# ['python', 'scala', 'golang']

# %%
"Line1\nLine2".splitlines()  # Returns: ['Line1', 'Line2']
# Out:
# ['Line1', 'Line2']

# %%
"AIAgents".startswith("AI")  # Returns: True
# Out:
# True

# %%
"PyThOn".swapcase()  # Returns: "pYtHoN"
# Out:
# 'pYtHoN'

# %%
table = str.maketrans("a", "x")
table
# Out:
# {97: 120}

# %%
table = str.maketrans("a", "x")
"apple".translate(table)  # Returns: "xpple"
# Out:
# 'xpple'

# %% [markdown]
# # string subscripte

# %%
word = 'Python'

# %%
word[0]
# Out:
# 'P'

# %%
word[-0]
# Out:
# 'P'

# %%
word[-1]
# Out:
# 'n'

# %%
word[1]
# Out:
# 'y'

# %%
word[1:]
# Out:
# 'ython'

# %%
word[-1:]
# Out:
# 'n'

# %%
word[-3:]
# Out:
# 'hon'

# %%
word[:-1]
# Out:
# 'Pytho'

# %%
word[:-2] #python
# Out:
# 'Pyth'

# %%
word[2:4] #python
# Out:
# 'th'

# %%
word[0:2]
# Out:
# 'Py'

# %%
"""
+---+---+---+---+---+---+
 | P | y | t | h | o | n |
 +---+---+---+---+---+---+
 0   1   2   3   4   5   6
-6  -5  -4  -3  -2  -1

"""
# Out:
# '\n+---+---+---+---+---+---+\n | P | y | t | h | o | n |\n +---+---+---+---+---+---+\n 0   1   2   3   4   5   6\n-6  -5  -4  -3  -2  -1\n\n'

# %%
"python".index('t')
# Out:
# 2

# %%
len('python')
# Out:
# 6

# %%
"python".index('t') - len('python')
# Out:
# -5
