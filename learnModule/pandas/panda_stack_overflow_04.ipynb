# %%
import pandas as pd
import os
from pathlib import Path
from pathlib import PurePosixPath



BASE_DIR = Path("../").resolve().parent

result_file_path = BASE_DIR / "resources" / "data" / "stack-overflow-survey" / "results.csv"
result_file_schema = BASE_DIR /  "resources" / "data" / "stack-overflow-survey" / "schema.csv"

BASE_DIR,result_file_path,result_file_schema
# Out:
# PosixPath('/home/suanki/Desktop/overflowwithpyspark')

# %%
df = pd.read_csv(result_file_path)
schema_df = pd.read_csv(result_file_schema)
# Out:
# /tmp/ipykernel_65133/407619006.py:1: DtypeWarning: Columns (0: JobSatPoints_15_TEXT, 1: DatabaseHaveEntry, 2: DevEnvHaveEntry, 3: SOTagsHaveEntry, 4: SOTagsWant Entry, 5: OfficeStackWantEntry, 6: CommPlatformHaveEntr, 7: CommPlatformWantEntr, 8: SO_Actions_15_TEXT, 9: AIAgentOrchestration, 10: AIAgentObsWrite) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(result_file_path)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=172)

# %%
df.shape #row and column
# Out:
# (49191, 172)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), str(119)
# memory usage: 64.6 MB

# %%
df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',139)
pd.set_option('display.max_colwidth',100)

# %%
df.head(1)
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
#
#                                            EdLevel Employment  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
#
#                                                                              LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning new coding techniques or programming language
#
#                                                                                              LearnCode  \
# 0  Online Courses or Certification (includes all media types);Other online resources (e.g. standard...
#
#                                                                            LearnCodeAI  \
# 0  Yes, I learned how to use AI-enabled tools for my personal curiosity and/or hobbies
#
# ...

# %%
schema_df.head()
# Out:
#      qid          qname  \
# 0  QID18  TechEndorse_1
# 1  QID18  TechEndorse_2
# 2  QID18  TechEndorse_3
# 3  QID18  TechEndorse_4
# 4  QID18  TechEndorse_5
#
#                                                                                    question  \
# 0  What attracts you to a technology or causes you to endorse it (most to least important)?
# 1  What attracts you to a technology or causes you to endorse it (most to least important)?
# 2  What attracts you to a technology or causes you to endorse it (most to least important)?
# 3  What attracts you to a technology or causes you to endorse it (most to least important)?
# 4  What attracts you to a technology or causes you to endorse it (most to least important)?
#
#   type                                      sub  sq_id
# 0   RO  AI integration or AI Agent capabilities    1.0
# 1   RO                          Easy-to-use API    2.0
# 2   RO                  Robust and complete API    3.0
# ...

# %%
df.shape
# Out:
# (49191, 172)

# %%
df['AIAgents']
# Out:
# 0         Yes, I use AI agents at work monthly or infrequently
# 1                                      No, and I don't plan to
# 2                          Yes, I use AI agents at work weekly
# 3         Yes, I use AI agents at work monthly or infrequently
# 4                                      No, and I don't plan to
#                                  ...
# 49186                                                      NaN
# 49187                                                      NaN
# 49188    No, I use AI exclusively in copilot/autocomplete mode
# 49189                                                      NaN
# 49190                                                      NaN
# Name: AIAgents, Length: 49191, dtype: str

# %%
df['AIAgents'].value_counts()
# Out:
# AIAgents
# No, and I don't plan to                                  12082
# No, but I plan to                                         5561
# Yes, I use AI agents at work daily                        4509
# No, I use AI exclusively in copilot/autocomplete mode     4401
# Yes, I use AI agents at work weekly                       2868
# Yes, I use AI agents at work monthly or infrequently      2498
# Name: count, dtype: int64

# %%
df.loc[0:3,['AIAgents']]
# Out:
#                                                AIAgents
# 0  Yes, I use AI agents at work monthly or infrequently
# 1                               No, and I don't plan to
# 2                   Yes, I use AI agents at work weekly
# 3  Yes, I use AI agents at work monthly or infrequently

# %%
df.loc[0:3,'TechEndorse_1':'AIAgents']
# Out:
#    TechEndorse_1  TechEndorse_2  TechEndorse_3  TechEndorse_4  TechEndorse_5  \
# 0           10.0            7.0            9.0            6.0            3.0
# 1           13.0            1.0            2.0            9.0            4.0
# 2           12.0            2.0            3.0            7.0            5.0
# 3            2.0           12.0            6.0            5.0           13.0
#
#    TechEndorse_6  TechEndorse_7  TechEndorse_8  TechEndorse_9  TechEndorse_13  \
# 0           11.0           12.0            1.0            8.0            14.0
# 1            3.0           12.0            5.0            7.0            14.0
# 2           10.0           13.0            1.0            4.0            14.0
# 3            3.0            8.0           11.0            7.0            14.0
#
#   TechEndorse_13_TEXT  TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# 0                 NaN          15.0           7.0           8.0          12.0
# ...
