# %%
import pandas as pd
import os
from pathlib import Path
from pathlib import PurePosixPath



BASE_DIR = Path("../").resolve().parent

result_file_path = BASE_DIR / "resources" / "data" / "stack-overflow-survey" / "results.csv"
result_file_schema = BASE_DIR /  "resources" / "data" / "stack-overflow-survey" / "schema.csv"

BASE_DIR,result_file_path,result_file_schema



pd.set_option('display.max_columns',170)
pd.set_option('display.max_rows',170)
pd.set_option('display.max_colwidth',172)
pd.set_option('display.max_seq_items', None)

survey_schema=pd.read_csv(result_file_schema,index_col='qname')
survey_df = pd.read_csv(result_file_path, index_col='ResponseId')

# %%
data = {
    "first": ["Ramesh","Rajesh","Mahesh"],
    "last" : ["Govardhan","singh","pablo"],
    "age": [23,34,25],
    "email": ["ramesh@mail.com","rajesh@mail.com","mahesh@mail.com"]

}

df = pd.DataFrame(data)
df
# Out:
#     first       last  age            email
# 0  Ramesh  Govardhan   23  ramesh@mail.com
# 1  Rajesh      singh   34  rajesh@mail.com
# 2  Mahesh      pablo   25  mahesh@mail.com

# %%
df.sort_values(by='age',ascending=True)
# Out:
#     first       last  age            email
# 0  Ramesh  Govardhan   23  ramesh@mail.com
# 2  Mahesh      pablo   25  mahesh@mail.com
# 1  Rajesh      singh   34  rajesh@mail.com

# %%
df.sort_values(by=['first','last'],ascending=True)
# Out:
#     first       last  age            email
# 2  Mahesh      pablo   25  mahesh@mail.com
# 1  Rajesh      singh   34  rajesh@mail.com
# 0  Ramesh  Govardhan   23  ramesh@mail.com

# %%
df.sort_values(by=['first','last'],ascending=[True,False], inplace=True) # first is asc and last is desc sorting

# %%
df
# Out:
#     first       last  age            email
# 2  Mahesh      pablo   25  mahesh@mail.com
# 1  Rajesh      singh   34  rajesh@mail.com
# 0  Ramesh  Govardhan   23  ramesh@mail.com

# %%
#reverse sor_value using sort_index

# %%
df.sort_index(inplace=True)

# %% [markdown]
# ## lets look at the survey data

# %%
survey_df.head(2)
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
#
#                                                             CodingActivities  \
# ResponseId
# 1                                                                      Hobby
# 2           Hobby;Contribute to open-source projects;Other (please specify):
#
#                                                  EdLevel  \
# ResponseId
# 1                              Primary/elementary school
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                                                                                              LearnCode  \
# ResponseId
# ...

# %%
survey_df.columns
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
#        'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse',
#        'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith',
#        'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'ToolsTechAdmired',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
# ...

# %%
survey_df.rename(columns={"ConvertedCompYearly":"SalaryUSD"}, inplace=True)

# %%
# sort the survey result by salary
df = survey_df[['SalaryUSD','Country','RemoteWork','Employment','LanguageHaveWorkedWith']]

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending=[True,False], inplace=True)

# %%
df[['Country','SalaryUSD']]
# Out:
#                 Country  SalaryUSD
# ResponseId
# 39346       Afghanistan    20000.0
# 37549       Afghanistan    11512.0
# 14673       Afghanistan     8634.0
# 6942        Afghanistan     6907.0
# 1566        Afghanistan     5940.0
# ...                 ...        ...
# 65431               NaN        NaN
# 65433               NaN        NaN
# 65434               NaN        NaN
# 65435               NaN        NaN
# 65437               NaN        NaN
#
# [65437 rows x 2 columns]

# %%
# 10 highest salary

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# ResponseId
# 15838    16256603.0
# 12724    13818022.0
# 28380     9000000.0
# 17594     6340564.0
# 17673     4936778.0
# 19268     3367716.0
# 23695     2584118.0
# 33721     2237846.0
# 34524     2153432.0
# 13764     2048046.0
# Name: SalaryUSD, dtype: float64
