# %% [markdown]
# ### Data Cleaning
#    Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# - Empty cells
# - Data in wrong format
# - Wrong data
# - Duplicates

# %%
import pandas as pd

# %%
df = pd.read_csv("bad_data.csv")

# %%
df
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
#
#                    Phone Date of birth              Job Title
# 1  +1-114-355-1841x78347      28-06-69     Broadcast engineer
# 2             9017807728      25-09-15       Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78  Multimedia specialist

# %%
# drop nan and invalid row
df.dropna()
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
#
#                    Phone Date of birth              Job Title
# 1  +1-114-355-1841x78347      28-06-69     Broadcast engineer
# 2             9017807728      25-09-15       Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78  Multimedia specialist

# %%
df = pd.read_csv('bad_data.csv')

df.dropna(inplace = True) # will not return new df, it's just replace the existing one

# %%
df
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
#
#                    Phone Date of birth              Job Title
# 1  +1-114-355-1841x78347      28-06-69     Broadcast engineer
# 2             9017807728      25-09-15       Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78  Multimedia specialist

# %%
df = pd.read_csv('bad_data.csv')

df.info()

df
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          5 non-null      int64
#  1   First Name     5 non-null      str
#  2   Last Name      5 non-null      str
#  3   Sex            5 non-null      str
#  4   Email          4 non-null      str
#  5   Phone          5 non-null      str
#  6   Date of birth  4 non-null      str
#  7   Job Title      5 non-null      str
# dtypes: int64(1), str(7)
# memory usage: 452.0 bytes
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female                          NaN
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
# ...

# %%
df.fillna("uknown", inplace = True)
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female                       uknown
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538        uknown  Planning and development surveyor

# %%
df = pd.read_csv('bad_data.csv')
df
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female                          NaN
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538           NaN  Planning and development surveyor

# %%
cleaned_df = df.fillna({"Email":"d@support.co.in"},inplace=False)

cleaned_df
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female              d@support.co.in
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538           NaN  Planning and development surveyor

# %%
cleaned_df
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female              d@support.co.in
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538           NaN  Planning and development surveyor

# %%
df = pd.read_json("employee_data.json")

df.head()
# Out:
#    position                                               text  \
# 0         1                                       Usually you:
# 1         2                              You more often allow:
# 2         3  When you decide to go somewhere for one day, y...
# 3         4                    Being in a company you usually:
# 4         5                     You can most likely be called:
#
#                                              answers
# 0  [{'position': 1, 'text': 'communicative'}, {'p...
# 1  [{'position': 1, 'text': 'feelings control you...
# 2  [{'position': 1, 'text': 'plan what and when y...
# 3  [{'position': 1, 'text': 'join the conversatio...
# 4  [{'position': 1, 'text': 'practical person'}, ...

# %%
df['position'].mean()
# Out:
# np.float64(37.5)

# %%
df['position'].median()
# Out:
# np.float64(37.5)

# %%
df['position'].mean()
# Out:
# np.float64(37.5)

# %%
wrong_data = {
    "name": ["Ramesh","Rajoo","Kalpesh","Somesh","Randheer"],
    "age": [22, 34, 78, 89, 34],
    "salary": [ 2000, 1500, None,1600, 1300],
    "doj": ["2026-05-21", "20260620", "2022-05-30", None, "20221204"],
    "email": [ "ramesh@mail.com", "rajoo@mail.com", "kalpesh@mail", None,"randheer@mail.com"]
}


df = pd.DataFrame(wrong_data)

# %%
df
# Out:
#        name  age  salary         doj              email
# 0    Ramesh   22  2000.0  2026-05-21    ramesh@mail.com
# 1     Rajoo   34  1500.0    20260620     rajoo@mail.com
# 2   Kalpesh   78     NaN  2022-05-30       kalpesh@mail
# 3    Somesh   89  1600.0         NaN                NaN
# 4  Randheer   34  1300.0    20221204  randheer@mail.com

# %%
"""Let's try to convert all cells in the 'Date' column into dates.

Pandas has a to_datetime() method for this:"""
# Out:
# "Let's try to convert all cells in the 'Date' column into dates.\n\nPandas has a to_datetime() method for this:"

# %%
pd.to_datetime(df['doj'], format="mixed") #NaT ==> not a time
# Out:
# 0   2026-05-21
# 1   2026-06-20
# 2   2022-05-30
# 3          NaT
# 4   2022-12-04
# Name: doj, dtype: datetime64[us]

# %%
df.dropna(subset=['doj','salary'], inplace = True)

# %%
df
# Out:
#        name  age  salary         doj              email
# 0    Ramesh   22  2000.0  2026-05-21    ramesh@mail.com
# 1     Rajoo   34  1500.0    20260620     rajoo@mail.com
# 4  Randheer   34  1300.0    20221204  randheer@mail.com

# %% [markdown]
# # set duration and replace

# %%
df.loc[1,'age']=40

# %%
df
# Out:
#        name  age  salary         doj              email
# 0    Ramesh   22  2000.0  2026-05-21    ramesh@mail.com
# 1     Rajoo   40  1500.0    20260620     rajoo@mail.com
# 4  Randheer   34  1300.0    20221204  randheer@mail.com

# %%
df.loc['age']
# Out:
# 0    22
# 1    40
# 4    34
# Name: age, dtype: int64

# %%
for idx in df.index:
    print(idx)
    print(df.loc[idx])
    print()
# Out:
# 0
# name               Ramesh
# age                    22
# salary             2000.0
# doj            2026-05-21
# email     ramesh@mail.com
# Name: 0, dtype: object
#
# 1
# name               Rajoo
# age                   40
# salary            1500.0
# doj             20260620
# email     rajoo@mail.com
# Name: 1, dtype: object
#
# 4
# name               Randheer
# age                      34
# salary               1300.0
# doj                20221204
# email     randheer@mail.com
# Name: 4, dtype: object

# %%
#removing the row


df.drop(1, inplace=True)
df
# Out:
#        name  age  salary       doj              email
# 4  Randheer   34  1300.0  20221204  randheer@mail.com

# %%
# Removing Duplicates

wrong_data = {
    "name": ["Ramesh","Rajoo","Kalpesh","Somesh","Ramesh"],
    "age": [22, 34, 78, 89, 22],
    "salary": [ 2000, 1500, None,1600, 2000],
    "doj": ["2026-05-21", "20260620", "2022-05-30", None, "2026-05-21"],
    "email": [ "ramesh@mail.com", "rajoo@mail.com", "kalpesh@mail", None,"ramesh@mail.com"]
}


df = pd.DataFrame(wrong_data)

# %%
df
# Out:
#       name  age  salary         doj            email
# 0   Ramesh   22  2000.0  2026-05-21  ramesh@mail.com
# 1    Rajoo   34  1500.0    20260620   rajoo@mail.com
# 2  Kalpesh   78     NaN  2022-05-30     kalpesh@mail
# 3   Somesh   89  1600.0         NaN              NaN
# 4   Ramesh   22  2000.0  2026-05-21  ramesh@mail.com

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
df
# Out:
#       name  age  salary         doj            email
# 0   Ramesh   22  2000.0  2026-05-21  ramesh@mail.com
# 1    Rajoo   34  1500.0    20260620   rajoo@mail.com
# 2  Kalpesh   78     NaN  2022-05-30     kalpesh@mail
# 3   Somesh   89  1600.0         NaN              NaN
# 4   Ramesh   22  2000.0  2026-05-21  ramesh@mail.com

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#       name  age  salary         doj            email
# 0   Ramesh   22  2000.0  2026-05-21  ramesh@mail.com
# 1    Rajoo   34  1500.0    20260620   rajoo@mail.com
# 2  Kalpesh   78     NaN  2022-05-30     kalpesh@mail
# 3   Somesh   89  1600.0         NaN              NaN
