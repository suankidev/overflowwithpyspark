# %%
import pandas as pd

file = r"C:\Users\sujee\Desktop\spark_input\stack-overflow-developer-survey-2019"

df = pd.read_csv(file+r"\survey_results_public.csv", index_col='Respondent')

df_schema = pd.read_csv(file+r"\survey_results_schema.csv",index_col='Column')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df_schema
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df.tail(5)
# Out:
#            MainBranch Hobbyist  \
# Respondent
# 88377             NaN      Yes
# 88601             NaN       No
# 88802             NaN       No
# 88816             NaN       No
# 88863             NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 88377       Less than once a month but more than once per ...
# 88601                                                   Never
# 88802                                                   Never
# 88816                                                   Never
# 88863                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 88377       The quality of OSS and closed source software ...
# 88601       The quality of OSS and closed source software ...
# 88802                                                     NaN
# 88816       OSS is, on average, of HIGHER quality than pro...
# ...

# %%
person = {
    "first" : "sujeet",
    "last": "singh",
    "email": "sujeet.kumar@abc.com"
}



people ={
    
    "first" : ["sujeet",'Ramesh'],
    "last": ["singh",'kumar'],
    "email": ["sujeet.kumar@abc.com", 'ramesh@gmail.com']
    
}


people_df = pd.DataFrame(people)

people_df
# Out:
#     first   last                 email
# 0  sujeet  singh  sujeet.kumar@abc.com
# 1  Ramesh  kumar      ramesh@gmail.com

# %%
type(people_df)
# Out:
# pandas.core.frame.DataFrame

# %%
people_df['email']
# Out:
# 0    sujeet.kumar@abc.com
# 1        ramesh@gmail.com
# Name: email, dtype: object

# %%
type(people_df['email'])
# Out:
# pandas.core.series.Series

# %%
people_df.email
# Out:
# 0    sujeet.kumar@abc.com
# 1        ramesh@gmail.com
# Name: email, dtype: object

# %%
people_df[['email','first']]   #passing a list of column to access multiple column and no longer 
                                #be series(b/c single column in row
# Out:
#                   email   first
# 0  sujeet.kumar@abc.com  sujeet
# 1      ramesh@gmail.com  Ramesh

# %%
type(people_df[['email','first']]  )
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
#how to get row

#loc
#iloc


print(type(people_df.iloc[0]))

people_df.iloc[0]
# Out:
# <class 'pandas.core.series.Series'>
# first                  sujeet
# last                    singh
# email    sujeet.kumar@abc.com
# Name: 0, dtype: object

# %%
people_df.iloc[[0,1]]
# Out:
#     first   last                 email
# 0  sujeet  singh  sujeet.kumar@abc.com
# 1  Ramesh  kumar      ramesh@gmail.com

# %%
people_df.iloc[[0,1], [2]] #list of row and second list is column
# Out:
#                   email
# 0  sujeet.kumar@abc.com
# 1      ramesh@gmail.com

# %%
people_df
# Out:
#     first   last                 email
# 0  sujeet  singh  sujeet.kumar@abc.com
# 1  Ramesh  kumar      ramesh@gmail.com

# %%
people_df.loc[0]
# Out:
# first                  sujeet
# last                    singh
# email    sujeet.kumar@abc.com
# Name: 0, dtype: object

# %%
people_df.loc[[0,1]]
# Out:
#     first   last                 email
# 0  sujeet  singh  sujeet.kumar@abc.com
# 1  Ramesh  kumar      ramesh@gmail.com

# %%
people_df.loc[[0,1],['email']]
# Out:
#                   email
# 0  sujeet.kumar@abc.com
# 1      ramesh@gmail.com

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.loc[0,'Hobbyist']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\pyspark_dev_env\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\pyspark_dev_env\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\pyspark_dev_env\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.loc[0:2, 'Hobbyist':'Employment']

# %%
people_df

# %%
#set index 

people_df.set_index('email',inplace=True)

print(people_df.loc['ramesh@gmail.com'])

# %%
people_df.index

# %%
people_df.reset_index(inplace=True)

people_df

# %%
df_schema.loc['Hobbyist']

# %%
df_schema.sort_index(ascending=False)

# %%
people_df.reset_index(inplace=True)
print(people_df.index)

# %%
first =(people_df['first'] == 'sujeet') | (people_df['first'] == 'Ramesh') 

print(first)
people_df.loc[first]

# %%
df_schema

# %%
high_sal = (df['ConvertedComp'] > 70000)

df.loc(high_sal,['ConvertedComp','DevType'])

# %%
import pandas as pd
import numpy as np


def read_file():
    path = r"C:\Users\sujee\Desktop\spark_input\stack-overflow-developer-survey-2019"
    df = pd.read_csv(path + r"\survey_results_public.csv", index_col='Respondent')
    df_schema = pd.read_csv(path + r"\survey_results_schema.csv", index_col='Column')
    pd.set_option('display.max_columns', 85)
    pd.set_option('display.max_rows', 85)

    return df, df_schema



df_schema

# %%
df, df_schema = read_file()
country = ['India', 'Germany', 'Canada']
high_sal = (df['ConvertedComp'] > 70000) & (df['Country'].isin(country)) \
      & (df['LanguageWorkedWith'].str.contains('Python', na=False))

# %%
df.loc[high_sal,['Country','LanguageWorkedWith','ConvertedComp']]

# %%
people_df

people_df.columns = [i.upper() for i in people_df.columns]

people_df.columns = people_df.columns.str.replace(' ','_')

people_df
# Out:
#     FIRST   LAST                 EMAIL
# 0  sujeet  singh  sujeet.kumar@abc.com
# 1  Ramesh  kumar      ramesh@gmail.com

# %%
people_df.rename(columns={'FIRST':'first_name','LAST':'last_name','EMAIL':'email'},inplace=True)

# %%
people_df
# Out:
#   first_name last_name                 email
# 0     sujeet     singh  sujeet.kumar@abc.com
# 1     Ramesh     kumar      ramesh@gmail.com

# %%
people_df.loc[1]
# Out:
# first_name              Ramesh
# last_name                kumar
# email         ramesh@gmail.com
# Name: 1, dtype: object

# %%
people_df.loc[1] = ['John','smith','john@gmail.com']

# %%
people_df
# Out:
#   first_name last_name                 email
# 0     sujeet     singh  sujeet.kumar@abc.com
# 1       John     smith        john@gmail.com

# %%
people_df.loc[2, ['last_name','email']] = ['Doe','JohnDoe@email.com']

# %%
people_df
# Out:
#   first_name last_name                 email last
# 0     sujeet     singh  sujeet.kumar@abc.com  NaN
# 1       John     smith        john@gmail.com  NaN
# 2        NaN       Doe     JohnDoe@email.com  Doe

# %%
people_df.at[2,'first_name'] = 'Correy'

# %%
people_df
# Out:
#   first_name last_name                 email last
# 0     sujeet     singh  sujeet.kumar@abc.com  NaN
# 1       John     smith        john@gmail.com  NaN
# 2     Correy       Doe     JohnDoe@email.com  Doe

# %%
people_df['email'].apply(len)
# Out:
# 0    20
# 1    14
# 2    17
# Name: email, dtype: int64

# %%
def update_email(e):
    return e.upper()

people_df['email']=people_df['email'].apply(update_email)


people_df
# Out:
#   first_name last_name                 email last
# 0     sujeet     singh  SUJEET.KUMAR@ABC.COM  NaN
# 1       John     smith        JOHN@GMAIL.COM  NaN
# 2     Correy       Doe     JOHNDOE@EMAIL.COM  Doe

# %%
#people_df.rename(columns={'last':'full_name'}, inplace=True)

people_df['full_name']=people_df['first'] + ' ' + people_df['last']

# %%
people_df
# Out:
#     first   last                 email     full_name
# 0  sujeet  singh  sujeet.kumar@abc.com  sujeet singh
# 1  Ramesh  kumar      ramesh@gmail.com  Ramesh kumar

# %%
people_df.applymap(str.upper)
# Out:
#     first   last                 email     full_name
# 0  SUJEET  SINGH  SUJEET.KUMAR@ABC.COM  SUJEET SINGH
# 1  RAMESH  KUMAR      RAMESH@GMAIL.COM  RAMESH KUMAR

# %%
people_df['first'].map(str.lower)
# Out:
# 0    sujeet
# 1    ramesh
# Name: first, dtype: object

# %%
people_df.drop(index=people_df[people_df['last'] == 'kumar'].index)
# Out:
#     first   last                 email     full_name
# 0  sujeet  singh  sujeet.kumar@abc.com  sujeet singh
