# %%
num = 3

type(num)
# Out:
# int

# %%
num = 3.4
type(num)
# Out:
# float

# %%
num = 3 % 2 # remaninder or modulus

num
# Out:
# 1

# %%
num = 17 // 7  # floor division
num
# Out:
# 2

# %%
num = 3 / 2
num
# Out:
# 1.5

# %%
num = 3 ** 2

num
# Out:
# 9

# %%
num *= 10

# %%
round(3.765, 2)
# Out:
# 3.77
