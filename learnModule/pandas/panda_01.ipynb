# %%
import pandas 
import pandas as pd 
import pathlib

# %%
BASE_DIR = pathlib.Path("../").resolve().parent

RESOURCE_DIR = BASE_DIR / "resources"


data_csv = RESOURCE_DIR / "data" / "data.csv"

bad_data_csv = RESOURCE_DIR / "data" / "bad_data.csv"


employee_data_json = RESOURCE_DIR / "data" / "employee_data.json"

# %%
df = pd.read_csv(data_csv)

df.head()
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female           tsharp@example.net
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538      17-11-89  Planning and development surveyor

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

myvar
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
myvar[0]
# Out:
# np.int64(1)

# %%
a = [1,2,3]

myvar = pd.Series(a, index = ['x','y','z'])

myvar
# Out:
# x    1
# y    2
# z    3
# dtype: int64

# %%
myvar['x']
# Out:
# np.int64(1)

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)

# %%
myvar
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
# only use data from day1 and day2

myvar = pd.Series(calories, index = ["day1", "day2"])

myvar
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
vars = pd.Series([1,2,3], index = ['x','y','z'])

vars
# Out:
# x    1
# y    2
# z    3
# dtype: int64

# %%
vars['x']
# Out:
# np.int64(1)

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.loc[0] #return panda Series
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
df.loc[[0, 1]] #return panda dataframe
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

# %%
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df.loc['day2']
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
df.loc[['day2','day1']]
# Out:
#       calories  duration
# day2       380        40
# day1       420        50

# %%
pd.options.display.max_rows
# Out:
# 10

# %%
pd.options.display.max_rows = 10

# %%
df = pd.read_csv(data_csv)

# %%
df
# Out:
#       Index First Name  Last Name     Sex                        Email  \
# 0         1       Sara    Mcguire  Female           tsharp@example.net
# 1         2     Alisha     Hebert    Male   vincentgarrett@example.net
# 2         3  Gwendolyn   Sheppard    Male  mercadojonathan@example.com
# 3         4   Kristine     Mccann  Female        lindsay55@example.com
# 4         5      Bobby    Pittman  Female    blevinsmorgan@example.com
# ...     ...        ...        ...     ...                          ...
# 9995   9996       Tina    Sherman    Male  bartlettcolleen@example.org
# 9996   9997       Earl   Jennings  Female     andreabenton@example.com
# 9997   9998      Ellen  Dominguez  Female    michaelayoder@example.net
# 9998   9999       Emma      Clark    Male      pstrickland@example.com
# 9999  10000    Katrina   Schwartz  Female         andres56@example.org
#
#                        Phone Date of birth                          Job Title
# ...

# %%
display(df)
# Out:
#       Index First Name  Last Name     Sex                        Email  \
# 0         1       Sara    Mcguire  Female           tsharp@example.net
# 1         2     Alisha     Hebert    Male   vincentgarrett@example.net
# 2         3  Gwendolyn   Sheppard    Male  mercadojonathan@example.com
# 3         4   Kristine     Mccann  Female        lindsay55@example.com
# 4         5      Bobby    Pittman  Female    blevinsmorgan@example.com
# ...     ...        ...        ...     ...                          ...
# 9995   9996       Tina    Sherman    Male  bartlettcolleen@example.org
# 9996   9997       Earl   Jennings  Female     andreabenton@example.com
# 9997   9998      Ellen  Dominguez  Female    michaelayoder@example.net
# 9998   9999       Emma      Clark    Male      pstrickland@example.com
# 9999  10000    Katrina   Schwartz  Female         andres56@example.org
#
#                        Phone Date of birth                          Job Title
# ...

# %%
employee_data_json
# Out:
# PosixPath('/home/suanki/Desktop/overflowwithpyspark/resources/data/employee_data.json')

# %%
df_json = pd.read_json(employee_data_json)

# %%
df_json
# Out:
#     position                                               text  \
# 0          1                                       Usually you:
# 1          2                              You more often allow:
# 2          3  When you decide to go somewhere for one day, y...
# 3          4                    Being in a company you usually:
# 4          5                     You can most likely be called:
# ..       ...                                                ...
# 69        70                                          Your age.
# 70        71                                       Your gender.
# 71        72                                    Marital Status.
# 72        73                                    I am dependent.
# 73        74                             Financial Obligations.
#
#                                               answers
# 0   [{'position': 1, 'text': 'communicative'}, {'p...
# 1   [{'position': 1, 'text': 'feelings control you...
# ...

# %%
pd.set_option("display.max_colwidth",100)

# %%
display(df_json)
# Out:
#     position                                                       text  \
# 0          1                                               Usually you:
# 1          2                                      You more often allow:
# 2          3  When you decide to go somewhere for one day, you usually:
# 3          4                            Being in a company you usually:
# 4          5                             You can most likely be called:
# ..       ...                                                        ...
# 69        70                                                  Your age.
# 70        71                                               Your gender.
# 71        72                                            Marital Status.
# 72        73                                            I am dependent.
# 73        74                                     Financial Obligations.
#
#                                                                                                 answers
# ...

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female           tsharp@example.net
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538      17-11-89  Planning and development surveyor

# %%
df.tail()
# Out:
#       Index First Name  Last Name     Sex                        Email  \
# 9995   9996       Tina    Sherman    Male  bartlettcolleen@example.org
# 9996   9997       Earl   Jennings  Female     andreabenton@example.com
# 9997   9998      Ellen  Dominguez  Female    michaelayoder@example.net
# 9998   9999       Emma      Clark    Male      pstrickland@example.com
# 9999  10000    Katrina   Schwartz  Female         andres56@example.org
#
#                        Phone Date of birth                 Job Title
# 9995      (455)476-4044x5755      28-07-74  Scientist, physiological
# 9996            009.056.6505      20-08-32         Warehouse manager
# 9997        409-428-4297x469      06-06-66                    Lawyer
# 9998            849-868-8653      09-05-07     Accounting technician
# 9999  001-874-330-5546x16770      14-08-35         Drilling engineer

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          10000 non-null  int64
#  1   First Name     10000 non-null  str
#  2   Last Name      10000 non-null  str
#  3   Sex            10000 non-null  str
#  4   Email          10000 non-null  str
#  5   Phone          10000 non-null  str
#  6   Date of birth  10000 non-null  str
#  7   Job Title      10000 non-null  str
# dtypes: int64(1), str(7)
# memory usage: 625.1 KB

# %%
df.shape
# Out:
# (10000, 8)
