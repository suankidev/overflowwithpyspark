# %%
import pandas as pd
import os
from pathlib import Path
from pathlib import PurePosixPath



BASE_DIR = Path("../").resolve().parent

result_file_path = BASE_DIR / "resources" / "data" / "stack-overflow-survey" / "results.csv"
result_file_schema = BASE_DIR /  "resources" / "data" / "stack-overflow-survey" / "schema.csv"

BASE_DIR,result_file_path,result_file_schema
# Out:
# (PosixPath('/home/suanki/Desktop/overflowwithpyspark'),
#  PosixPath('/home/suanki/Desktop/overflowwithpyspark/resources/data/stack-overflow-survey/results.csv'),
#  PosixPath('/home/suanki/Desktop/overflowwithpyspark/resources/data/stack-overflow-survey/schema.csv'))

# %%
pd.set_option('display.max_columns',170)
pd.set_option('display.max_rows',170)
pd.set_option('display.max_colwidth',172)

df_schema=pd.read_csv(result_file_schema,index_col='qname')
df = pd.read_csv(result_file_path, index_col='ResponseId')

# %%
df_schema=pd.read_csv(result_file_schema,index_col='qname')
df_schema.head()
# Out:
#                qid                                           question  \
# qname
# MainBranch    QID2  Which of the following options best describes ...
# Age         QID127                                 What is your age?*
# Employment  QID296  Which of the following best describes your cur...
# RemoteWork  QID308  Which best describes your current work situation?
# Check       QID341  Just checking to make sure you are paying atte...
#
#            force_resp type selector
# qname
# MainBranch       True   MC     SAVR
# Age              True   MC     SAVR
# Employment       True   MC     MAVR
# RemoteWork      False   MC     SAVR
# Check            True   MC     SAVR

# %%
df=pd.read_csv(result_file_path)
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
#        'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse',
#        'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith',
#        'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'ToolsTechAdmired',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
# ...

# %%
df = pd.read_csv(result_file_path, index_col='ResponseId')

# %%
df_schema.index
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
#        'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse',
#        'Country', 'Currency', 'CompTotal', 'Language', 'Database', 'Platform',
#        'Webframe', 'Embedded', 'MiscTech', 'ToolsTech', 'NEWCollabTools',
#        'OpSys', 'OfficeStackAsync', 'OfficeStackSync', 'AISearchDev',
#        'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOHow',
#        'SOComm', 'AISelect', 'AISent', 'AIBen', 'AIAcc', 'AIComplex', 'AITool',
#        'AINext', 'AIThreat', 'AIEthics', 'AIChallenges', 'TBranch', 'ICorPM',
#        'WorkExp', 'Knowledge', 'Frequency', 'TimeSearching', 'TimeAnswering',
#        'Frustration', 'ProfessionalTech', 'ProfessionalCloud',
#        'ProfessionalQuestion', 'Industry', 'JobSat', 'JobSatPoints',
# ...

# %%
df.index
# Out:
# RangeIndex(start=1, stop=65438, step=1, name='ResponseId')

# %%
list(df.columns)
# Out:
# ['MainBranch',
#  'Age',
#  'Employment',
#  'RemoteWork',
#  'Check',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'TechDoc',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'BuyNewTool',
#  'BuildvsBuy',
#  'TechEndorse',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'LanguageAdmired',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'DatabaseAdmired',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'PlatformAdmired',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'WebframeAdmired',
#  'EmbeddedHaveWorkedWith',
#  'EmbeddedWantToWorkWith',
#  'EmbeddedAdmired',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'MiscTechAdmired',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'ToolsTechAdmired',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
# ...

# %%
# Tell pandas to display everything in a sequence/index
pd.set_option('display.max_seq_items', None)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
#        'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse',
#        'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith',
#        'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'ToolsTechAdmired',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
# ...

# %%
df_schema.loc['AIThreat','question']
# Out:
# 'Do you believe AI is a threat to your current job?'

# %%
df['AIThreat'].value_counts()
# Out:
# AIThreat
# No              30423
# I'm not sure     8878
# Yes              5388
# Name: count, dtype: int64

# %%
df_schema.sort_index(inplace=True)

# %%
df_schema.index
# Out:
# Index(['AIAcc', 'AIBen', 'AIChallenges', 'AIComplex', 'AIEthics', 'AINext',
#        'AISearchDev', 'AISelect', 'AISent', 'AIThreat', 'AITool', 'Age',
#        'BuildvsBuy', 'BuyNewTool', 'Check', 'CodingActivities', 'CompTotal',
#        'Country', 'Currency', 'Database', 'DevType', 'EdLevel', 'Embedded',
#        'Employment', 'Frequency', 'Frequency_1', 'Frequency_2', 'Frequency_3',
#        'Frustration', 'ICorPM', 'Industry', 'JobSat', 'JobSatPoints',
#        'JobSatPoints_1', 'JobSatPoints_10', 'JobSatPoints_11',
#        'JobSatPoints_4', 'JobSatPoints_5', 'JobSatPoints_6', 'JobSatPoints_7',
#        'JobSatPoints_8', 'JobSatPoints_9', 'Knowledge', 'Knowledge_1',
#        'Knowledge_2', 'Knowledge_3', 'Knowledge_4', 'Knowledge_5',
#        'Knowledge_6', 'Knowledge_7', 'Knowledge_8', 'Knowledge_9', 'Language',
#        'LearnCode', 'LearnCodeOnline', 'MainBranch', 'MiscTech',
#        'NEWCollabTools', 'NEWSOSites', 'OfficeStackAsync', 'OfficeStackSync',
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
#        'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse',
#        'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith',
#        'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'ToolsTechAdmired',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
# ...

# %%
df_schema.loc['Language','question']
# Out:
# 'Which <b>programming, scripting, and markup languages</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1                                                      NaN
# 2        Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                       C#
# 4        C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                  C++;HTML/CSS;JavaScript;Lua;Python;Rust
#                                ...
# 65433                                                  NaN
# 65434                                                  NaN
# 65435                                                  NaN
# 65436             C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65437     C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: str

# %% [markdown]
# ## Filtering

# %%
df_schema.loc['CompTotal','question']
# Out:
# 'What is your current total <b>annual</b> compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent yearly salary. If you prefer not to answer, please leave the box empty. '

# %%
filter_by_high_salary = (df['ConvertedCompYearly'] > 70000)

countries_list = ['United States','India', 'United Kingdom', 'Germany']

filter_by_country = df['Country'].isin(countries_list)

filter_by_language = df['LanguageHaveWorkedWith'].str.contains('Scala', na=False)

filter_by_high_salary_and_countries = filter_by_high_salary & filter_by_country & filter_by_language

# %%
filter_by_high_salary_and_countries
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 65433    False
# 65434    False
# 65435    False
# 65436    False
# 65437    False
# Length: 65437, dtype: bool

# %%
df.loc[filter_by_high_salary_and_countries, ['Country','Currency','LanguageHaveWorkedWith', 'CompTotal', 'ConvertedCompYearly']]
# Out:
#             Country           Currency  \
# ResponseId
# 4037        Germany  EUR European Euro
# 7061        Germany  EUR European Euro
# 8006        Germany  EUR European Euro
# 8519          India  INR\tIndian rupee
# 11983       Germany  EUR European Euro
# 12636       Germany  EUR European Euro
# 15398       Germany  EUR European Euro
# 15713       Germany  EUR European Euro
# 16042       Germany  EUR European Euro
# 17192       Germany  EUR European Euro
# 17395       Germany  EUR European Euro
# 20276       Germany  EUR European Euro
# 20901       Germany  EUR European Euro
# 21671       Germany  EUR European Euro
# 21880       Germany  EUR European Euro
# 22089       Germany  EUR European Euro
# 22402       Germany  EUR European Euro
# 22405       Germany  EUR European Euro
# 22991       Germany  EUR European Euro
# 22998       Germany  EUR European Euro
# 23340       Germany  EUR European Euro
# 23651       Germany  EUR European Euro
# 23841       Germany  EUR European Euro
# ...
