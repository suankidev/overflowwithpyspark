# %%
import pandas as pd

data = {
    "first": ["Ramesh","Rajesh","Mahesh"],
    "last" : ["Govardhan","singh","pablo"],
    "age": [23,34,25],
    "email": ["ramesh@mail.com","rajesh@mail.com","mahesh@mail.com"]

}

df = pd.DataFrame(data)
df
# Out:
#     first       last  age            email
# 0  Ramesh  Govardhan   23  ramesh@mail.com
# 1  Rajesh      singh   34  rajesh@mail.com
# 2  Mahesh      pablo   25  mahesh@mail.com

# %%
df
# Out:
#     first       last  age            email
# 0  Ramesh  Govardhan   23  ramesh@mail.com
# 1  Rajesh      singh   34  rajesh@mail.com
# 2  Mahesh      pablo   25  mahesh@mail.com

# %%
df.apply(len)
# Out:
# first    3
# last     3
# age      3
# email    3
# dtype: int64

# %%
x = 20 if True  else 20

# %%
df.map(lambda x:  len(str(x)) if isinstance(x, (int,float))  else len(x))
# Out:
#    first  last  age  email
# 0      6     9    2     15
# 1      6     5    2     15
# 2      6     5    2     15

# %%
df
# Out:
#     first       last  age            email
# 0  Ramesh  Govardhan   23  ramesh@mail.com
# 1  Rajesh      singh   34  rajesh@mail.com
# 2  Mahesh      pablo   25  mahesh@mail.com

# %%
df['first'].map({"Rajesh":"Kajoo"}) #rest become non, so we should use replace to avoid that
# Out:
# 0      NaN
# 1    Kajoo
# 2      NaN
# Name: first, dtype: str

# %%
df['first'] = df['first'].replace({"Ramesh":"Kajoo"})

# %%
df
# Out:
#     first       last  age            email
# 0   Kajoo  Govardhan   23  ramesh@mail.com
# 1  Rajesh      singh   34  rajesh@mail.com
# 2  Mahesh      pablo   25  mahesh@mail.com

# %%
df['isAge'] = df['age'].apply(lambda x: True if x>30 else False)


df
# Out:
#     first       last  age            email  isAge
# 0   Kajoo  Govardhan   23  ramesh@mail.com  False
# 1  Rajesh      singh   34  rajesh@mail.com   True
# 2  Mahesh      pablo   25  mahesh@mail.com  False
