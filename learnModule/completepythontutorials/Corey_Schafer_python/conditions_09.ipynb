# %% [markdown]
# ## More on Conditions
#
# - The conditions used in while and if statements can contain any operators, not just comparisons.
# - The comparison operators in and not in are membership tests

# %%
string1, string2, string3 = '', 'Trondheim', 'Hammer Dance'

# %%
string1 or string2
# Out:
# 'Trondheim'

# %%
string2 or string3
# Out:
# 'Trondheim'

# %%
a = "Hello"
b = "Hello"

a is b
# Out:
# True

# %%
x = 10
y = "Hello"

x is y
# Out:
# False

# %%
x = 10
y = 10

x is y
# Out:
# True

# %%
id(x) , id(y)
# Out:
# (9667152, 9667152)

# %% [markdown]
# ### Comparing Sequences and Other Types
#
# - Sequence objects typically may be compared to other objects with the same sequence type.
# - The comparison uses lexicographical ordering: first the first two items are compared, and if they differ this determines the outcome of the comparison; if they are equal, the next two items are compared, and so on, until either sequence is exhausted

# %%
(1, 2, 3) < (1, 2, 4)
# Out:
# True

# %%
[1, 2, 3] < [1, 2, 4]
# Out:
# True

# %%
# checking from left to right
# A -> 65 , C -> 67 so, 65< 67  that becom true, rest doesn't matter
# C -> 67, P -> larger number 
# p== P, a < y ..so this is true
'ABC' < 'C' < 'Pascal' < 'Python'
# Out:
# True

# %%
(1, 2, 3) == (1.0, 2.0, 3.0)
# Out:
# True
